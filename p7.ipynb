# %%
def f(x, y):
    return (x - 10) ** 2 + (y + 2) ** 2

def f_gd(x, y, lr, itr):
    """
    Gradient descent for f(x, y)
    x, y: start point
    lr: learning rate
    itr: number of iterations
    """
    print('f value: {}\n'.format(f(x, y)))
    for i in range(itr):
        grad_x = 2 * x - 20
        grad_y = 2 * y + 4
        
        x = x - lr * grad_x
        y = y - lr * grad_y
        
        print('Iteration: {}'.format(i + 1))
        print('x: {}, y: {}'.format(x, y))
        print('f value: {}\n'.format(f(x, y)))

# %%
def g(x, y):
    return (x - 10) ** 2 + (x - y + 5) ** 4

def g_gd(x, y, lr, itr):
    """
    Gradient descent for g(x, y)
    x, y: start point
    lr: learning rate
    itr: number of iterations
    """
    print('g value: {}\n'.format(g(x, y)))
    for i in range(itr):
        grad_x = 2 * x - 20 + 4 * (x - y + 5) ** 3
        grad_y = 4 * -1 * (x - y + 5)
        
        x = x - lr * grad_x
        y = y - lr * grad_y
        
        print('Iteration: {}'.format(i + 1))
        print('x: {}, y: {}'.format(x, y))
        print('g value: {}\n'.format(g(x, y)))

# %% [markdown]
# ## Start with (x, y) = (0, 0), learning rate = 0.5

# %%
f_gd(0, 0, 0.5, 10)
# Out:
# f value: 104
#
# Iteration: 1
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 2
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 3
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 4
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 5
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 6
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 7
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 8
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 9
# x: 10.0, y: -2.0
# f value: 0.0
#
# Iteration: 10
# x: 10.0, y: -2.0
# f value: 0.0

# %%
g_gd(0, 0, 0.5, 10)
# Out:
# g value: 725
#
# Iteration: 1
# x: -240.0, y: 10.0
# g value: 3603063125.0
#
# Iteration: 2
# x: 29412260.0, y: -480.0
# g value: 7.48414565397836e+29
#
# Iteration: 3
# x: -5.0890494266878875e+22, y: 58825010.0
# g value: 6.707283691682731e+90
#
# Iteration: 4
# x: 2.6359672030334484e+68, y: -1.017809885337578e+23
# g value: 4.827919383901375e+273
#
# Iteration: 5
# x: -3.663110359146689e+205, y: 5.271934406066897e+68
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-4-ec697f412fc3> in <module>
# ----> 1 g_gd(0, 0, 0.5, 10)
#
# <ipython-input-2-9f3618b11c46> in g_gd(x, y, lr, itr)
#      19         print('Iteration: {}'.format(i + 1))
#      20         print('x: {}, y: {}'.format(x, y))
# ---> 21         print('g value: {}\n'.format(g(x, y)))
#
# <ipython-input-2-9f3618b11c46> in g(x, y)
#       1 def g(x, y):
# ...

# %% [markdown]
# ## Adjust learning rate and test 10 and 100 epochs for function f

# %%
f_gd(0, 0, 0.4, 10)
# Out:
# f value: 104
#
# Iteration: 1
# x: 8.0, y: -1.6
# f value: 4.16
#
# Iteration: 2
# x: 9.6, y: -1.92
# f value: 0.1664000000000003
#
# Iteration: 3
# x: 9.92, y: -1.984
# f value: 0.006656000000000012
#
# Iteration: 4
# x: 9.984, y: -1.9968
# f value: 0.0002662400000000011
#
# Iteration: 5
# x: 9.9968, y: -1.99936
# f value: 1.064959999999771e-05
#
# Iteration: 6
# x: 9.99936, y: -1.999872
# f value: 4.2598400000079516e-07
#
# Iteration: 7
# x: 9.999872, y: -1.9999744
# f value: 1.7039360000036356e-08
#
# Iteration: 8
# x: 9.9999744, y: -1.99999488
# f value: 6.815744000373793e-10
#
# Iteration: 9
# x: 9.99999488, y: -1.999998976
# f value: 2.7262976008589227e-11
#
# Iteration: 10
# x: 9.999998976, y: -1.9999997952
# f value: 1.0905190389247573e-12

# %%
f_gd(0, 0, 0.4, 100)
# Out:
# f value: 104
#
# Iteration: 1
# x: 8.0, y: -1.6
# f value: 4.16
#
# Iteration: 2
# x: 9.6, y: -1.92
# f value: 0.1664000000000003
#
# Iteration: 3
# x: 9.92, y: -1.984
# f value: 0.006656000000000012
#
# Iteration: 4
# x: 9.984, y: -1.9968
# f value: 0.0002662400000000011
#
# Iteration: 5
# x: 9.9968, y: -1.99936
# f value: 1.064959999999771e-05
#
# Iteration: 6
# x: 9.99936, y: -1.999872
# f value: 4.2598400000079516e-07
#
# Iteration: 7
# x: 9.999872, y: -1.9999744
# f value: 1.7039360000036356e-08
#
# Iteration: 8
# x: 9.9999744, y: -1.99999488
# f value: 6.815744000373793e-10
#
# Iteration: 9
# x: 9.99999488, y: -1.999998976
# f value: 2.7262976008589227e-11
#
# Iteration: 10
# x: 9.999998976, y: -1.9999997952
# f value: 1.0905190389247573e-12
#
# Iteration: 11
# x: 9.9999997952, y: -1.99999995904
# f value: 4.3620761269589974e-14
#
# Iteration: 12
# x: 9.99999995904, y: -1.999999991808
# f value: 1.7448304500560031e-15
#
# Iteration: 13
# x: 9.999999991808, y: -1.9999999983616
# ...

# %%
f_gd(0, 0, 0.3, 10)
# Out:
# f value: 104
#
# Iteration: 1
# x: 6.0, y: -1.2
# f value: 16.64
#
# Iteration: 2
# x: 8.4, y: -1.68
# f value: 2.662399999999999
#
# Iteration: 3
# x: 9.36, y: -1.8719999999999999
# f value: 0.42598400000000075
#
# Iteration: 4
# x: 9.744, y: -1.9487999999999999
# f value: 0.06815744000000014
#
# Iteration: 5
# x: 9.8976, y: -1.97952
# f value: 0.010905190399999876
#
# Iteration: 6
# x: 9.95904, y: -1.991808
# f value: 0.0017448304640000083
#
# Iteration: 7
# x: 9.983616, y: -1.9967232
# f value: 0.00027917287424001356
#
# Iteration: 8
# x: 9.9934464, y: -1.99868928
# f value: 4.4667659878402054e-05
#
# Iteration: 9
# x: 9.99737856, y: -1.999475712
# f value: 7.146825580546239e-06
#
# Iteration: 10
# x: 9.998951424, y: -1.9997902848
# f value: 1.143492092888143e-06

# %%
f_gd(0, 0, 0.3, 100)
# Out:
# f value: 104
#
# Iteration: 1
# x: 6.0, y: -1.2
# f value: 16.64
#
# Iteration: 2
# x: 8.4, y: -1.68
# f value: 2.662399999999999
#
# Iteration: 3
# x: 9.36, y: -1.8719999999999999
# f value: 0.42598400000000075
#
# Iteration: 4
# x: 9.744, y: -1.9487999999999999
# f value: 0.06815744000000014
#
# Iteration: 5
# x: 9.8976, y: -1.97952
# f value: 0.010905190399999876
#
# Iteration: 6
# x: 9.95904, y: -1.991808
# f value: 0.0017448304640000083
#
# Iteration: 7
# x: 9.983616, y: -1.9967232
# f value: 0.00027917287424001356
#
# Iteration: 8
# x: 9.9934464, y: -1.99868928
# f value: 4.4667659878402054e-05
#
# Iteration: 9
# x: 9.99737856, y: -1.999475712
# f value: 7.146825580546239e-06
#
# Iteration: 10
# x: 9.998951424, y: -1.9997902848
# f value: 1.143492092888143e-06
#
# Iteration: 11
# x: 9.999580569599999, y: -1.99991611392
# f value: 1.8295873486271384e-07
#
# Iteration: 12
# x: 9.999832227839999, y: -1.999966445568
# f value: 2.9273397578272633e-08
#
# Iteration: 13
# ...

# %%
f_gd(0, 0, 0.6, 10)
# Out:
# f value: 104
#
# Iteration: 1
# x: 12.0, y: -2.4
# f value: 4.16
#
# Iteration: 2
# x: 9.6, y: -1.92
# f value: 0.1664000000000003
#
# Iteration: 3
# x: 10.08, y: -2.016
# f value: 0.006656000000000012
#
# Iteration: 4
# x: 9.984, y: -1.9968
# f value: 0.0002662400000000011
#
# Iteration: 5
# x: 10.0032, y: -2.00064
# f value: 1.0649599999997995e-05
#
# Iteration: 6
# x: 9.99936, y: -1.9998719999999999
# f value: 4.25984000000852e-07
#
# Iteration: 7
# x: 10.000128, y: -2.0000256
# f value: 1.7039360000024988e-08
#
# Iteration: 8
# x: 9.9999744, y: -1.99999488
# f value: 6.815744000373793e-10
#
# Iteration: 9
# x: 10.00000512, y: -2.000001024
# f value: 2.7262976008589227e-11
#
# Iteration: 10
# x: 9.999998976, y: -1.9999997952
# f value: 1.0905190389247573e-12

# %%
f_gd(0, 0, 0.6, 100)
# Out:
# f value: 104
#
# Iteration: 1
# x: 12.0, y: -2.4
# f value: 4.16
#
# Iteration: 2
# x: 9.6, y: -1.92
# f value: 0.1664000000000003
#
# Iteration: 3
# x: 10.08, y: -2.016
# f value: 0.006656000000000012
#
# Iteration: 4
# x: 9.984, y: -1.9968
# f value: 0.0002662400000000011
#
# Iteration: 5
# x: 10.0032, y: -2.00064
# f value: 1.0649599999997995e-05
#
# Iteration: 6
# x: 9.99936, y: -1.9998719999999999
# f value: 4.25984000000852e-07
#
# Iteration: 7
# x: 10.000128, y: -2.0000256
# f value: 1.7039360000024988e-08
#
# Iteration: 8
# x: 9.9999744, y: -1.99999488
# f value: 6.815744000373793e-10
#
# Iteration: 9
# x: 10.00000512, y: -2.000001024
# f value: 2.7262976008589227e-11
#
# Iteration: 10
# x: 9.999998976, y: -1.9999997952
# f value: 1.0905190389247573e-12
#
# Iteration: 11
# x: 10.0000002048, y: -2.00000004096
# f value: 4.362076125140008e-14
#
# Iteration: 12
# x: 9.99999995904, y: -1.999999991808
# f value: 1.7448304500560031e-15
#
# Iteration: 13
# ...

# %%
f_gd(0, 0, 0.7, 10)
# Out:
# f value: 104
#
# Iteration: 1
# x: 14.0, y: -2.8
# f value: 16.64
#
# Iteration: 2
# x: 8.4, y: -1.6800000000000002
# f value: 2.6623999999999985
#
# Iteration: 3
# x: 10.64, y: -2.128
# f value: 0.42598400000000075
#
# Iteration: 4
# x: 9.744, y: -1.9487999999999999
# f value: 0.06815744000000014
#
# Iteration: 5
# x: 10.1024, y: -2.02048
# f value: 0.010905190399999876
#
# Iteration: 6
# x: 9.95904, y: -1.991808
# f value: 0.0017448304640000083
#
# Iteration: 7
# x: 10.016384, y: -2.0032768
# f value: 0.00027917287424001356
#
# Iteration: 8
# x: 9.9934464, y: -1.99868928
# f value: 4.4667659878402054e-05
#
# Iteration: 9
# x: 10.00262144, y: -2.000524288
# f value: 7.146825580546006e-06
#
# Iteration: 10
# x: 9.998951424, y: -1.9997902848
# f value: 1.143492092888143e-06

# %%
f_gd(0, 0, 0.7, 100)
# Out:
# f value: 104
#
# Iteration: 1
# x: 14.0, y: -2.8
# f value: 16.64
#
# Iteration: 2
# x: 8.4, y: -1.6800000000000002
# f value: 2.6623999999999985
#
# Iteration: 3
# x: 10.64, y: -2.128
# f value: 0.42598400000000075
#
# Iteration: 4
# x: 9.744, y: -1.9487999999999999
# f value: 0.06815744000000014
#
# Iteration: 5
# x: 10.1024, y: -2.02048
# f value: 0.010905190399999876
#
# Iteration: 6
# x: 9.95904, y: -1.991808
# f value: 0.0017448304640000083
#
# Iteration: 7
# x: 10.016384, y: -2.0032768
# f value: 0.00027917287424001356
#
# Iteration: 8
# x: 9.9934464, y: -1.99868928
# f value: 4.4667659878402054e-05
#
# Iteration: 9
# x: 10.00262144, y: -2.000524288
# f value: 7.146825580546006e-06
#
# Iteration: 10
# x: 9.998951424, y: -1.9997902848
# f value: 1.143492092888143e-06
#
# Iteration: 11
# x: 10.000419430400001, y: -2.00008388608
# f value: 1.8295873486271384e-07
#
# Iteration: 12
# x: 9.999832227839999, y: -1.999966445568
# f value: 2.9273397578272633e-08
#
# Iteration: 13
# ...

# %% [markdown]
# ## Adjust learning rate and test 10 and 100 epochs for function g

# %%
g_gd(0, 0, 0.02, 10)
# Out:
# g value: 725
#
# Iteration: 1
# x: -9.6, y: 0.4
# g value: 1009.1600000000001
#
# Iteration: 2
# x: 1.184000000000001, y: 0.0
# g value: 1540.1614063247368
#
# Iteration: 3
# x: -17.38237100032001, y: 0.4947200000000001
# g value: 28245.891745063807
#
# Iteration: 4
# x: 154.53471893475785, y: -0.5354472800256009
# g value: 656531249.9876276
#
# Iteration: 5
# x: -327962.5369757197, y: 12.270166017157075
# g value: 1.1570055916294553e+22
#
# Iteration: 6
# x: 2822224647013579.0, y: -26225.31440532179
# g value: 6.34404596989665e+61
#
# Iteration: 7
# x: -1.7983106983494966e+45, y: 225777971736959.44
# g value: 1.045824741310213e+181
#
# Iteration: 8
# x: 4.6524763146661094e+134, y: -1.4386485586795974e+44
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-13-c2e87e2b494b> in <module>
# ----> 1 g_gd(0, 0, 0.02, 10)
#
# ...

# %%
g_gd(0, 0, 0.0195, 10)
# Out:
# g value: 725
#
# Iteration: 1
# x: -9.36, y: 0.39
# g value: 883.87600625
#
# Iteration: 2
# x: -0.24555374999999913, y: 0.019500000000000017
# g value: 607.6150367338465
#
# Iteration: 3
# x: -8.126156865821107, y: 0.3888258075000001
# g value: 481.2061376525058
#
# Iteration: 4
# x: -4.031854803110951, y: 0.11465715898095374
# g value: 197.42357671652317
#
# Iteration: 5
# x: -3.5331063441272743, y: 0.18122922593778515
# g value: 185.8771549112215
#
# Iteration: 6
# x: -3.171074338080665, y: 0.2815110514727105
# g value: 179.21079104536219
#
# Iteration: 7
# x: -2.9464136446950455, y: 0.40220939108754716
# g value: 175.0464054799787
#
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-20-82ad1618b8ca> in <module>
# ----> 1 g_gd(0, 0, 0.03, 10)
#
# <ipython-input-2-9f3618b11c46> in g_gd(x, y, lr, itr)
#      19         print('Iteration: {}'.format(i + 1))
#      20         print('x: {}, y: {}'.format(x, y))
# ...

# %%
g_gd(0, 0, 0.04, 100)
# Out:
# g value: 725
#
# Iteration: 1
# x: -19.2, y: 0.8
# g value: 51477.64
#
# Iteration: 2
# x: 523.136, y: -1.5999999999999999
# g value: 78747976623.19028
#
# Iteration: 3
# x: -23784259.99459844, y: 83.15776000000001
# g value: 3.200105403862168e+29
#
# Iteration: 4
# x: 2.152748003068437e+21, y: -3805410.946617351
# g value: 2.1476958609933245e+85
#
# Iteration: 5
# x: -1.596245065698045e+63, y: 3.4443968049094676e+20
# g value: 6.492295386567112e+252
#
# Iteration: 6
# x: 6.507567566991854e+188, y: -2.553992105116872e+62
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-21-a5c3631ae7cb> in <module>
# ----> 1 g_gd(0, 0, 0.04, 100)
#
# <ipython-input-2-9f3618b11c46> in g_gd(x, y, lr, itr)
#      19         print('Iteration: {}'.format(i + 1))
#      20         print('x: {}, y: {}'.format(x, y))
# ---> 21         print('g value: {}\n'.format(g(x, y)))
#
# ...

# %%
g_gd(0, 0, 0.01, 10)
# Out:
# g value: 725
#
# Iteration: 1
# x: -4.8, y: 0.2
# g value: 219.04000000000002
#
# Iteration: 2
# x: -4.504, y: 0.2
# g value: 210.37369256345596
#
# Iteration: 3
# x: -4.21495737344, y: 0.21184000000000003
# g value: 202.17296562443755
#
# Iteration: 4
# x: -3.938191512855746, y: 0.23476810506240006
# g value: 194.74103289469835
#
# Iteration: 5
# x: -3.682055368297689, y: 0.2678497203456742
# g value: 188.41458489779313
#
# Iteration: 6
# x: -3.454731818839281, y: 0.3098535167999397
# g value: 183.35924552626773
#
# Iteration: 7
# x: -3.2610592177217836, y: 0.3592701033743709
# g value: 179.4789702567398
#
# Iteration: 8
# x: -3.100885672234172, y: 0.4144569305305247
# g value: 176.49173648426859
#
# Iteration: 9
# x: -2.9697676827625865, y: 0.4738432264199368
# g value: 174.082638743007
#
# Iteration: 10
# x: -2.861176907031798, y: 0.5360987900526358
# g value: 172.0082205416484

# %%
g_gd(0, 0, 0.01, 100)
# Out:
# g value: 725
#
# Iteration: 1
# x: -4.8, y: 0.2
# g value: 219.04000000000002
#
# Iteration: 2
# x: -4.504, y: 0.2
# g value: 210.37369256345596
#
# Iteration: 3
# x: -4.21495737344, y: 0.21184000000000003
# g value: 202.17296562443755
#
# Iteration: 4
# x: -3.938191512855746, y: 0.23476810506240006
# g value: 194.74103289469835
#
# Iteration: 5
# x: -3.682055368297689, y: 0.2678497203456742
# g value: 188.41458489779313
#
# Iteration: 6
# x: -3.454731818839281, y: 0.3098535167999397
# g value: 183.35924552626773
#
# Iteration: 7
# x: -3.2610592177217836, y: 0.3592701033743709
# g value: 179.4789702567398
#
# Iteration: 8
# x: -3.100885672234172, y: 0.4144569305305247
# g value: 176.49173648426859
#
# Iteration: 9
# x: -2.9697676827625865, y: 0.4738432264199368
# g value: 174.082638743007
#
# Iteration: 10
# x: -2.861176907031798, y: 0.5360987900526358
# g value: 172.0082205416484
#
# Iteration: 11
# x: -2.76863170054626, y: 0.6002077621692585
# g value: 170.11719856846392
#
# ...
